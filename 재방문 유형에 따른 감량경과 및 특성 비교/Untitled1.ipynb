# %%
from BasisFilter import BasisFilter
import pandas as pd
import os
import copy
import numpy as np
import re
BF = BasisFilter()

# %%
basis = pd.read_csv(f'{BF.path}//filtered_data//21.03.01~24.06.24_basis_for_filter.csv')
basis_all = pd.read_csv(f'{BF.path}//filtered_data//21.03.01~24.06.24_basis_all.csv')
# Out:
# C:\Users\howsr\AppData\Local\Temp\ipykernel_48912\2725678678.py:1: DtypeWarning: Columns (2,5,11,12,131,132,159,160,161,162,189,190,191,192,219,220,221,222,249,250,251,252,279,280,281,282,309,310,311,312,339,340,341,342,369,370,371,372,399,400,401,402,429,430,431,432,459,460,461,462,489,490,491,492,519,520,521,522,549,550,551,552,579,580,581,582,609,610,611,612,639,640,641,642,669,670,671,672,699,700,701,702,729,730,731,732,759,760,761,762,789,790,791,792) have mixed types. Specify dtype option on import or set low_memory=False.
#   basis = pd.read_csv(f'{BF.path}//filtered_data//21.03.01~24.06.24_basis_for_filter.csv')
# ...

# %%
basis
# Out:
#          Region  PatientID PatientChartNo PatientName  \
# 0       bundang     340595          98856         박서연
# 1       bundang     150640          98441         오진숙
# 2       bundang      11851          38598         주정실
# 3       bundang     344256          99493         김현진
# 4       bundang     344966          99494         신은복
# ...         ...        ...            ...         ...
# 221468  incheon      23886         4323.0         이해민
# 221469  incheon      23041         4321.0         신은선
# 221470  incheon      23880         4320.0         이세연
# 221471  incheon      23900         4324.0         엄지현
# 221472  incheon      23905         4325.0         전민혁
#
#                                 PatientAddr11 PatientFirstDate   Age  \
# 0          경기도 광주시 오포읍 태재로 20-15 (이편한세상태재1단지)       2021-02-06  27.0
# 1                   경기도 화성시 동탄순환대로28길 17 (영천동       2021-01-26  38.0
# 2       충청북도 청주시 청원구 오창읍 오창중앙로 65 (우림필유2차아파트)       2016-12-31  34.0
# ...
