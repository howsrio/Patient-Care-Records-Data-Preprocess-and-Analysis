# %%
basis = pd.read_csv(f'{BF.path}\\MergeRegionData\\basis_for_filter.csv')
# Out:
# C:\Users\howsr\AppData\Local\Temp\ipykernel_38716\3606335970.py:1: DtypeWarning: Columns (1,67,68,69,70,97,98,99,100,127,128,129,130,157,158,159,160,187,188,189,190,217,218,219,220,247,248,249,250,277,278,279,280,307,308,309,310,337,338,339,340,367,368,369,370,397,398,399,400,427,428,429,430,457,458,459,460,487,488,489,490,517,518,519,520,547,548,549,550,577,578,579,580,607,608,609,610,637,638,639,640,667,668,669,670,697,698,699,700,727,728,729,730,757,758,759,760,787,788,789,790) have mixed types. Specify dtype option on import or set low_memory=False.
#   basis = pd.read_csv(f'{BF.path}\\MergeRegionData\\basis_for_filter.csv')

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import os
import copy
from BasisFilter import BasisFilter

# %%
BF = BasisFilter()
BF.newPath
# Out:
# 'C:\\Users\\howsr\\workspace\\1_DataPreprocessing\\basis\\filtered_data'

# %%
first_df = BF.first_visit_filter(basis)

# %%
first_df
# Out:
#          Region PatientChartNo  \
# 134     bundang         116010
# 277     bundang         116324
# 358     bundang         117948
# 726     bundang           4612
# 755     bundang         119857
# ...         ...            ...
# 130073  incheon         3958.0
# 130076  incheon         3959.0
# 130077  incheon         3961.0
# 130078  incheon         3962.0
# 130079  incheon         3963.0
#
#                                          PatientAddr11 PatientFirstDate   Age  \
# 134                   경기도 시흥시 정왕신길로49번길 26(정왕동, 미주아파트)       2022-11-11  37.0
# 277                       경기도 광주시 태봉로 110(태전동, 태전아이파크)       2022-11-28  43.0
# 358            경기도 안양시 동안구 관악대로318번길 8(관양동, 이너스내안에아파트)       2023-02-25  56.0
# 726                 경기도 성남시 중원구 황송로 77 (금광동, 래미안금광아파트)       2023-07-31  16.0
# 755                          경기도 하남시 미사강변한강로 155 (망월동)       2023-05-22  30.0
# ...                                                ...              ...   ...
# 130073  경기도 김포시 양촌읍 황금로89번길 25 (김포양촌 금빛마을 자연앤 데시앙 아파트)       2024-05-13  21.0
# 130076        경기도 동두천시 이담로 161 (지행동, 동두천 에코 휴먼빌2차 아파트)       2024-05-14  49.0
# 130077               인천광역시 남동구 석산로222번길 53 (구월동, 행복꿈터)       2024-05-14  33.0
# 130078               인천광역시 남동구 석산로222번길 53 (구월동, 행복꿈터)       2024-05-14  39.0
# 130079                   인천광역시 연수구 선학로 37 (선학동, 대진아파트)       2024-05-14  29.0
#
#         PatientSex                 Description      Date_1  \
# 134              2                         비대면  2022-11-11
# 277              1  S,J/내원경로 윤수비(잠69211/핸5242)  2022-11-28
# 358              2                         NaN  2023-02-25
# 726              2                         NaN  2023-07-31
# 755              2                   내원경로 건너건너  2023-05-22
# ...            ...                         ...         ...
# 130073           2                         비대면  2024-05-14
# 130076           2                         비대면  2024-05-14
# 130077           2                         NaN  2024-05-14
# 130078           1                         NaN  2024-05-14
# 130079           1                  비대면 ★빨간스티커  2024-05-14
#
#                                            ProgressNote_1  \
# 134     #비만\n\n여자\n\nㆍ 키/체중/BMI:161 / 55 / 정상(21.21831...
# 277     #비만\n\n남자\n\nㆍ 키/체중/BMI:178 / 102 / 중도 비만(32.1...
# 358     #비만\n\n여자\n\nㆍ 키/체중/BMI:157 / 52 / 정상(21.09619...
# 726     #비만\n\n여자\n\nㆍ 키/체중/BMI:166.9 / 97.7 / 고도 비만(3...
# 755     #비만\n\n여자\n\nㆍ 키/체중/BMI:164 / 54 / 정상(20.07733...
# ...                                                   ...
# 130073  # 비만(비대면초진)\n\n· 키/체중/BMI : 155 / 51 / 21.23\n...
# 130076  #비만(비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:156 / 72 / 경도비만...
# 130077  #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:162 / 73 / 경도비만(...
# 130078  #비만(내원초진)\n\n남자\n\nㆍ 키/체중/BMI:173 / 99.9 / 중도 ...
# 130079  # 비만(비대면초진)\n\n· 키/체중/BMI : 177 / 88 / 28.09\n...
#
#                                            MedicineName_1  ... Osseus_27  \
# 134              ['팻아웃 정1통*1   ', 'GambiTab-D4_1통*3#405']  ...       NaN
# 277              ['GambiTab-D6_1통*3#405', '팻아웃 정1통*1   ']  ...       NaN
# 358     ['GambiTab-D5_1통*2#270', '팻아웃 정1통*1   ', 'Gamb...  ...       NaN
# 726                               ['GambiTab-A_1통*3#405']  ...       NaN
# 755              ['팻아웃 정1통*1   ', 'GambiTab-D3_1통*3#405']  ...       NaN
# ...                                                   ...  ...       ...
# 130073  ['GambiTab-DLv8_1통*2#270', '팻아웃 정1통*1', '하루비움정...  ...       NaN
# 130076  ['GambiTab-DLv7_1통*3#405', 'GambiTab-DLv8_1통*3...  ...       NaN
# 130077                                                NaN  ...       NaN
# 130078                                                NaN  ...       NaN
# 130079                                                NaN  ...       NaN
#
#         ECW_TBW_27  ECF_TBF_27  VFA_27  WHR_27  WeightControl_27  \
# 134            NaN         NaN     NaN     NaN               NaN
# 277            NaN         NaN     NaN     NaN               NaN
# 358            NaN         NaN     NaN     NaN               NaN
# 726            NaN         NaN     NaN     NaN               NaN
# 755            NaN         NaN     NaN     NaN               NaN
# ...            ...         ...     ...     ...               ...
# 130073         NaN         NaN     NaN     NaN               NaN
# 130076         NaN         NaN     NaN     NaN               NaN
# 130077         NaN         NaN     NaN     NaN               NaN
# 130078         NaN         NaN     NaN     NaN               NaN
# 130079         NaN         NaN     NaN     NaN               NaN
#
#         FatControl_27  MuscleControl_27  BMR_27  FitnessScore_27
# 134               NaN               NaN     NaN              NaN
# 277               NaN               NaN     NaN              NaN
# 358               NaN               NaN     NaN              NaN
# 726               NaN               NaN     NaN              NaN
# 755               NaN               NaN     NaN              NaN
# ...               ...               ...     ...              ...
# 130073            NaN               NaN     NaN              NaN
# 130076            NaN               NaN     NaN              NaN
# 130077            NaN               NaN     NaN              NaN
# 130078            NaN               NaN     NaN              NaN
# 130079            NaN               NaN     NaN              NaN
#
# [44829 rows x 817 columns]
