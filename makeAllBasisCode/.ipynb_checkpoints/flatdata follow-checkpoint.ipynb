# %%
import numpy as np
import pandas as pd
import os 
import sys
import time
import matplotlib.pyplot as plt
from DataPreprocess import DataPreprocess

class mergeRegion:
    def __init__(self):
        self.path = os.getcwd()   # '\\region\\{}'.format(region)
        self.region_list = ['bucheon', 'bundang', 'busan', 'hongdae', 'jamsil', 'gangnam','incheon']
        self.path2 =os.path.abspath(os.path.join(self.path, "..", ".."))

    def makeDir(self):
        os.path.abspath(os.path.join(self.path, "..", ".."))
        self.newPath = os.path.join(f'{self.path2}\\MergeRegionData')
        if not os.path.exists(self.newPath):
            os.makedirs(os.path.join(f'{self.path2}\\MergeRegionData'))
        else:
            print('이미 존재합니다.')

    def delDir(self):
        self.newPath = os.path.join(f'{self.path2}\\MergeRegionData')
        # 'PreprocessData' 폴더가 존재하는지 확인하고 삭제
        if os.path.exists(self.newPath) and os.path.isdir(self.newPath):
            try:
                shutil.rmtree(self.newPath)
                print(f"'{self.newPath}' 폴더가 성공적으로 삭제되었습니다.")
            except Exception as e:
                print(f"폴더를 삭제하는 중 오류가 발생했습니다: {e}")
        else:
            print(f"'{self.newPath}' 폴더가 존재하지 않습니다.")

    def dataSet(self):

        self.preprocessPathList = []
        self.dataDict = {}
        for region in self.region_list:
            preprocessPath = os.path.join(f'{self.path2}\\region\\{region}\\PreprocessData\\{region}_merge.csv')
            self.preprocessPathList.append(preprocessPath)
            self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
            self.dataDict[region] = self.dataDict[region][~(self.dataDict[region]['ConsultTime'].isna())]

        self.fileList = self.preprocessPathList
        print('All files are added')
        return self.dataDict

    def regionCol(self):

        for region in self.region_list:
            df = self.dataDict[region]
            df['Region'] = f'{region}'

    def concatData(self):
        self.newPath = os.path.join(f'{self.path2}\\MergeRegionData')
        for i, region in enumerate(self.region_list):
            df = self.dataDict[region]
            if i == 0:
                concat_df = df
            else:
                concat_df = pd.concat([concat_df, df],axis = 0)
        self.concat_df = concat_df
        return self.concat_df

    def delZeroNaNCol(self, df):
        
        # 모든 원소가 NaN이거나 0인 열 삭제
        original_columns = df.columns  # 원본 열 이름 기억
        
        df_cleaned = df.dropna(axis=1, how='all')  # NaN 값이 모두인 열 삭제
        deleted_columns = original_columns.difference(df_cleaned.columns)  # 삭제된 열 찾기
        
        df_cleaned = df_cleaned.loc[:, (df_cleaned != 0).any(axis=0)]  # 0 값이 모두인 열 삭제
        deleted_columns = deleted_columns.union(original_columns.difference(df_cleaned.columns))  # 추가 삭제된 열 찾기
        
        print("\n처리된 데이터프레임:")
        print(df_cleaned)
        print("\n삭제된 열 이름:")
        print(deleted_columns)

# %%
# 병합 함수
def merge_rows(group):
    result = {'PatientID': group['PatientID'].iloc[0]}
    for col in group.columns:
        if col != 'PatientID':
            # 열 이름에 접미사 추가
            for i, value in enumerate(group[col], start=1):
                col_name = f"{col}_{i}"
                result[col_name] = value
    return result

# 최적화를 위한 데이터 처리
def process_and_merge(df, batch_size=1000):
    merged_results = []
    unique_ids = df['PatientID'].unique()
    
    for start in range(0, len(unique_ids), batch_size):
        end = start + batch_size
        batch_ids = unique_ids[start:end]
        batch_df = df[df['PatientID'].isin(batch_ids)]
        
        merged_results.extend([merge_rows(group) for _, group in batch_df.groupby('PatientID')])
    
    return pd.DataFrame(merged_results)

# %%
Merge = mergeRegion()
Merge.dataSet()
# Out:
# C:\Users\howsr\AppData\Local\Temp\ipykernel_21120\2926293893.py:42: DtypeWarning: Columns (28,54,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
# C:\Users\howsr\AppData\Local\Temp\ipykernel_21120\2926293893.py:42: DtypeWarning: Columns (4,28,56,62,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
# C:\Users\howsr\AppData\Local\Temp\ipykernel_21120\2926293893.py:42: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
# C:\Users\howsr\AppData\Local\Temp\ipykernel_21120\2926293893.py:42: DtypeWarning: Columns (28,62,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
# C:\Users\howsr\AppData\Local\Temp\ipykernel_21120\2926293893.py:42: DtypeWarning: Columns (8,28,62,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
# C:\Users\howsr\AppData\Local\Temp\ipykernel_21120\2926293893.py:42: DtypeWarning: Columns (28,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
# C:\Users\howsr\AppData\Local\Temp\ipykernel_21120\2926293893.py:42: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.dataDict[region] = pd.read_csv(preprocessPath, encoding='utf_8', index_col=0)
# All files are added
# {'bucheon':                  PatientID  ScheduleID          ConsultTime  ConsultNote  \
#  MedicalRecordID
#  876726.0                 9   1126286.0  2022-11-23 10:55:00          NaN
#  942106.0                 9   1195711.0  2023-02-16 09:45:00          NaN
#  943030.0                 9   1196745.0  2023-02-17 10:25:00          NaN
#  956320.0                 9   1210915.0  2023-03-07 19:20:00          NaN
#  956596.0                 9   1211226.0  2023-03-08 09:25:00          NaN
#  ...                    ...         ...                  ...          ...
#  1201055.0           243116   1490846.0  2024-05-14 15:45:00          NaN
#  1201001.0           243126   1490790.0  2024-05-14 14:45:00          NaN
#  1201040.0           243135   1490841.0  2024-05-14 15:35:00          NaN
#  1201076.0           243136   1490871.0  2024-05-14 16:00:00          NaN
#  1201146.0           243141   1490885.0  2024-05-14 17:25:00          NaN
#
#                                                        ProgressNote  Summary  \
#  MedicalRecordID
#  876726.0         # 비만\n\n현재체중 : 65kg\n마지막 약 복용일자 : 복용 중\n포만감&식사...      NaN
#  942106.0                                                       NaN      NaN
#  943030.0         # 비만\n\n현재체중 : 65kg\n마지막 약 복용일자 : 복용 중\n포만감&식사...      NaN
#  956320.0                                                       NaN      NaN
#  956596.0                                    # 비만\n\n>> 팻아웃플러스 9통        NaN
#  ...                                                            ...      ...
#  1201055.0        # 비만(비대면초진)\n\n· 키/체중/BMI : 158 / 55 / 22.03\n...      NaN
#  1201001.0        #비만(비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:153 / 58 / 과체중(...      NaN
#  1201040.0        #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:165 / 74 / 경도비만(...      NaN
#  1201076.0        #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:154 / 65 / 경도비만(...      NaN
#  1201146.0        #비만(내원초진) \n\n남자\n\nㆍ 키/체중/BMI:180 / 85 / 경도비만...      NaN
#
#                   RequestI  RequestII  TreatmentCat  Disclosure  ...   BMI  \
#  MedicalRecordID                                                 ...
#  876726.0             25.0        NaN           0.0         1.0  ...   NaN
#  942106.0             24.0        NaN           0.0         1.0  ...   NaN
#  943030.0              NaN        NaN           0.0         1.0  ...   NaN
#  956320.0              NaN        NaN           0.0         1.0  ...   NaN
#  956596.0              NaN        NaN           0.0         1.0  ...   NaN
#  ...                   ...        ...           ...         ...  ...   ...
#  1201055.0             NaN        NaN           0.0         1.0  ...   NaN
#  1201001.0             NaN        NaN           0.0         1.0  ...   NaN
#  1201040.0           207.0        NaN           0.0         1.0  ...  28.0
#  1201076.0             NaN        NaN           0.0         1.0  ...  28.4
#  1201146.0           207.0        NaN           0.0         1.0  ...  25.9
#
#                    SMM  BodyFat    VFA   WHR            CheckDate  \
#  MedicalRecordID
#  876726.0          NaN      NaN    NaN   NaN                  NaN
#  942106.0          NaN      NaN    NaN   NaN                  NaN
#  943030.0          NaN      NaN    NaN   NaN                  NaN
#  956320.0          NaN      NaN    NaN   NaN                  NaN
#  956596.0          NaN      NaN    NaN   NaN                  NaN
#  ...               ...      ...    ...   ...                  ...
#  1201055.0         NaN      NaN    NaN   NaN                  NaN
#  1201001.0         NaN      NaN    NaN   NaN                  NaN
#  1201040.0        28.2     24.7  116.7  0.95  2024-05-14 15:04:00
#  1201076.0        20.4     28.4  143.6  0.85  2024-05-14 16:05:00
#  1201146.0        37.1     18.5   77.5  0.89  2024-05-14 17:02:00
#
#                                CrTime  MaxVital  MinVital  Pulse
#  MedicalRecordID
#  876726.0                         NaN       NaN       NaN    NaN
#  942106.0                         NaN       NaN       NaN    NaN
#  943030.0                         NaN       NaN       NaN    NaN
#  956320.0                         NaN       NaN       NaN    NaN
#  956596.0                         NaN       NaN       NaN    NaN
#  ...                              ...       ...       ...    ...
#  1201055.0                        NaN       NaN       NaN    NaN
#  1201001.0                        NaN       NaN       NaN    NaN
#  1201040.0        2024-05-14 15:51:05     136.0      81.0   97.0
#  1201076.0        2024-05-14 16:07:23     142.0      84.0   92.0
#  1201146.0        2024-05-14 17:32:23     117.0      74.0   78.0
#
#  [85305 rows x 258 columns],
#  'bundang':                  PatientID  ScheduleID          ConsultTime ConsultNote  \
#  MedicalRecordID
#  2177976.0                8   2621930.0  2022-11-25 16:20:00         NaN
#  2216876.0                8   2661790.0  2023-01-03 14:25:00         NaN
#  2265531.0                8   2712706.0  2023-03-04 12:30:00         NaN
#  2580461.0                8   3052871.0  2024-03-13 17:30:00         NaN
#  2173431.0               15   2617481.0  2022-11-24 15:25:00         NaN
#  ...                    ...         ...                  ...         ...
#  2619900.0           484871   3098176.0  2024-05-14 18:30:00         NaN
#  2619771.0           484891   3098475.0  2024-05-14 16:35:00         NaN
#  2619746.0           484906   3098371.0  2024-05-14 16:15:00         NaN
#  2619780.0           484921   3098401.0  2024-05-14 16:40:00         NaN
#  2619885.0           484940   3098536.0  2024-05-14 18:10:00         NaN
#
#                                                        ProgressNote  Summary  \
#  MedicalRecordID
#  2177976.0        #비만\n\n신청 약 : 감비정 - D2X 405, 팻아웃 3, 부스터정 1\n차수...      NaN
#  2216876.0        # 비만\n\n신청 약 : 감비정 D2X 405, 부스터정 1\n차수 : 2-2차\...      NaN
#  2265531.0        # 비만\n\n현재체중 : 65kg\n마지막 약 복용일자 : 복용 중\n포만감&식사...      NaN
#  2580461.0        #비만(비대면초진)\n\n키: 160cm/ 체중: 78kg /BMI: 30.229 ...      NaN
#  2173431.0                                                      NaN      NaN
#  ...                                                            ...      ...
#  2619900.0        #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:168 / 62 / 정상(21...      NaN
#  2619771.0        #비만(비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:165 / 80 / 경도비만...      NaN
#  2619746.0        #비만(내원초진)\n\n\n남자\n\nㆍ 키/체중/BMI:181.7 / 98 / 경...      NaN
#  2619780.0        # 비만(비대면초진)\n\n· 키/체중/BMI : 159 / 65 / 25.71\n...      NaN
#  2619885.0        #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:167 / 77 / 경도비만(...      NaN
#
#                   RequestI  RequestII  TreatmentCat  Disclosure  ...   BMI  \
#  MedicalRecordID                                                 ...
#  2177976.0            59.0        NaN           0.0         1.0  ...   NaN
#  2216876.0            60.0        NaN           0.0         1.0  ...   NaN
#  2265531.0            59.0        NaN           0.0         1.0  ...   NaN
#  2580461.0           181.0        NaN           0.0         1.0  ...   NaN
#  2173431.0            59.0        NaN           0.0         1.0  ...   NaN
#  ...                   ...        ...           ...         ...  ...   ...
#  2619900.0           166.0        NaN           0.0         1.0  ...  22.2
#  2619771.0             NaN        NaN           0.0         1.0  ...   NaN
#  2619746.0             NaN        NaN           0.0         1.0  ...  30.7
#  2619780.0             NaN        NaN           0.0         1.0  ...   NaN
#  2619885.0           166.0        NaN           0.0         1.0  ...  27.5
#
#                    SMM  BodyFat    VFA   WHR  CheckDate  CrTime  MaxVital  \
#  MedicalRecordID
#  2177976.0         NaN      NaN    NaN   NaN        NaN     NaN       NaN
#  2216876.0         NaN      NaN    NaN   NaN        NaN     NaN       NaN
#  2265531.0         NaN      NaN    NaN   NaN        NaN     NaN       NaN
#  2580461.0         NaN      NaN    NaN   NaN        NaN     NaN       NaN
#  2173431.0         NaN      NaN    NaN   NaN        NaN     NaN       NaN
#  ...               ...      ...    ...   ...        ...     ...       ...
#  2619900.0        23.2     19.1   79.6  0.82        NaN     NaN       NaN
#  2619771.0         NaN      NaN    NaN   NaN        NaN     NaN       NaN
#  2619746.0        41.5     27.0  119.7  0.96        NaN     NaN       NaN
#  2619780.0         NaN      NaN    NaN   NaN        NaN     NaN       NaN
#  2619885.0        21.8     35.2  188.4  0.96        NaN     NaN       NaN
#
#                   MinVital  Pulse
#  MedicalRecordID
#  2177976.0             NaN    NaN
#  2216876.0             NaN    NaN
#  2265531.0             NaN    NaN
#  2580461.0             NaN    NaN
#  2173431.0             NaN    NaN
#  ...                   ...    ...
#  2619900.0             NaN    NaN
#  2619771.0             NaN    NaN
#  2619746.0             NaN    NaN
#  2619780.0             NaN    NaN
#  2619885.0             NaN    NaN
#
#  [120272 rows x 258 columns],
#  'busan':                  PatientID  ScheduleID          ConsultTime  ConsultNote  \
#  MedicalRecordID
#  180600.0                 7    207531.0  2023-02-22 15:25:00          NaN
#  187795.0                 7    214835.0  2023-04-01 09:25:00          NaN
#  230016.0                32    261886.0  2023-11-13 17:15:00          NaN
#  230150.0                32    262045.0  2023-11-14 10:35:00          NaN
#  184086.0                47    211261.0  2023-03-10 11:55:00          NaN
#  ...                    ...         ...                  ...          ...
#  257420.0             63551    292786.0  2024-05-14 14:45:00          NaN
#  257445.0             63561    292761.0  2024-05-14 15:10:00          NaN
#  257440.0             63566    292806.0  2024-05-14 15:05:00          NaN
#  257470.0             63585    292880.0  2024-05-14 15:50:00          NaN
#  257471.0             63590    292885.0  2024-05-14 16:00:00          NaN
#
#                                                        ProgressNote  Summary  \
#  MedicalRecordID
#  180600.0         # 비만\n\n*체      중: (  76.6  )\n*골격근량: (  25.9 ...      NaN
#  187795.0         # 비만\n\n*체      중: (  72.0  )  -4.6\n*골격근량: ( ...      NaN
#  230016.0         #비만(전화상담접수)\n\n*체     중: (   83kg   )\n\n\n* 식...      NaN
#  230150.0                                                       NaN      NaN
#  184086.0                                                       NaN      NaN
#  ...                                                            ...      ...
#  257420.0         #비만(전화상담접수)\n\n*체     중: (    85kg  )\n\n\n* 식...      NaN
#  257445.0         # 비만(비대면초진)\n\n· 주소 : 대구 중구 서성로 99 101동 1704호\...      NaN
#  257440.0         # 비만(비대면초진)\n\n· 주소 : 부산 부산진구 부전동 477-3 보성오페라 ...      NaN
#  257470.0         #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:162 / 65 / 과체중(2...      NaN
#  257471.0         #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:150 / 69 / 중도 비만...      NaN
#
#                   RequestI  RequestII  TreatmentCat  Disclosure  ...   BMI  \
#  MedicalRecordID                                                 ...
#  180600.0             30.0        NaN           0.0         1.0  ...  26.8
#  187795.0             29.0        NaN           0.0         1.0  ...  25.2
#  230016.0              NaN        NaN           0.0         1.0  ...   NaN
#  230150.0              NaN        NaN           0.0         1.0  ...   NaN
#  184086.0              NaN        NaN           0.0         1.0  ...   NaN
#  ...                   ...        ...           ...         ...  ...   ...
#  257420.0             30.0        NaN           0.0         1.0  ...   NaN
#  257445.0              NaN        NaN           0.0         1.0  ...   NaN
#  257440.0             39.0        NaN           0.0         1.0  ...   NaN
#  257470.0              5.0        NaN           0.0         1.0  ...  26.3
#  257471.0              NaN        NaN           0.0         1.0  ...  29.5
#
#                    SMM  BodyFat    VFA   WHR            CheckDate  \
#  MedicalRecordID
#  180600.0         25.9     29.4  137.9  0.90  2023-02-22 15:00:00
#  187795.0         25.5     25.6  122.2  0.93  2023-04-01 09:00:00
#  230016.0          NaN      NaN    NaN   NaN                  NaN
#  230150.0          NaN      NaN    NaN   NaN                  NaN
#  184086.0          NaN      NaN    NaN   NaN                  NaN
#  ...               ...      ...    ...   ...                  ...
#  257420.0          NaN      NaN    NaN   NaN                  NaN
#  257445.0          NaN      NaN    NaN   NaN                  NaN
#  257440.0          NaN      NaN    NaN   NaN                  NaN
#  257470.0         23.3     23.9  116.1  0.89  2024-05-14 14:01:00
#  257471.0         23.5     26.5  133.7  0.90  2024-05-14 15:01:05
#
#                                CrTime  MaxVital  MinVital  Pulse
#  MedicalRecordID
#  180600.0         2023-02-22 15:28:37     137.0      80.0   83.0
#  187795.0         2023-04-01 09:22:39     132.0      79.0  105.0
#  230016.0                         NaN       NaN       NaN    NaN
#  230150.0                         NaN       NaN       NaN    NaN
#  184086.0                         NaN       NaN       NaN    NaN
#  ...                              ...       ...       ...    ...
#  257420.0                         NaN       NaN       NaN    NaN
#  257445.0                         NaN       NaN       NaN    NaN
#  257440.0                         NaN       NaN       NaN    NaN
#  257470.0         2024-05-14 16:11:26     146.0      91.0   85.0
#  257471.0         2024-05-14 16:18:01     111.0      64.0   90.0
#
#  [23205 rows x 258 columns],
#  'hongdae':                  PatientID  ScheduleID          ConsultTime  ConsultNote  \
#  MedicalRecordID
#  1413375.0                7   1792070.0  2022-11-23 19:20:00          NaN
#  1446736.0                7   1827011.0  2023-01-02 16:00:00          NaN
#  1421521.0               20   1800216.0  2022-11-28 17:55:00          NaN
#  1470086.0               20   1852825.0  2023-02-07 14:35:00          NaN
#  1421354.0               22   1800064.0  2022-11-28 14:45:00          NaN
#  ...                    ...         ...                  ...          ...
#  1756011.0           342820   2169391.0  2024-05-14 15:40:00          NaN
#  1755940.0           342825   2169275.0  2024-05-14 14:40:00          NaN
#  1756005.0           342826   2169301.0  2024-05-14 15:35:00          NaN
#  1756196.0           342831   2169350.0  2024-05-14 18:25:00          NaN
#  1756245.0           342856   2169546.0  2024-05-14 19:10:00          NaN
#
#                                                        ProgressNote  Summary  \
#  MedicalRecordID
#  1413375.0        # 비만\n\n현재체중 : 62\n포만감 또는 식욕조절 :잘안됨\n불편사항 : 무\...      NaN
#  1446736.0        # 비만\n\n현재체중 : 61kg\n마지막 약 복용일자 : 복용 중\n포만감&식사...      NaN
#  1421521.0         \n# 비만\n\n현재체중 : 78\n마지막 약 복용일자 : 1개월 이상\n포만감...      NaN
#  1470086.0         \n# 비만\n\n현재체중 : 74kg\n마지막 약 복용일자 : 복용 중\n포만감...      NaN
#  1421354.0        # 비만\n\n*현재 체중: 57kg\n*최근 6개월 내 다이어트 약 복용 유무 :...      NaN
#  ...                                                            ...      ...
#  1756011.0        #비만(비대면초진)\n\n남자\n\nㆍ 키/체중/BMI:175 / 95 / 중도 비...      NaN
#  1755940.0        #비만(내원초진)\n\n남자\n\nㆍ 키/체중/BMI:170 / 91 / 중도 비만...      NaN
#  1756005.0        # 비만(비대면초진)\n\n· 키/체중/BMI : 173 / 88 / 29.40\n...      NaN
#  1756196.0        #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:166 / 76 / 경도비만(...      NaN
#  1756245.0        #비만(내원초진)\n\n남자\n\nㆍ 키/체중/BMI:175 / 80 / 경도비만(...      NaN
#
#                   RequestI  RequestII  TreatmentCat  Disclosure  ...   BMI  \
#  MedicalRecordID                                                 ...
#  1413375.0             NaN        NaN           0.0         1.0  ...   NaN
#  1446736.0            87.0        NaN           0.0         1.0  ...   NaN
#  1421521.0            50.0        NaN           0.0         1.0  ...   NaN
#  1470086.0             NaN        NaN           0.0         1.0  ...   NaN
#  1421354.0            50.0        NaN           0.0         1.0  ...   NaN
#  ...                   ...        ...           ...         ...  ...   ...
#  1756011.0             NaN        NaN           0.0         1.0  ...   NaN
#  1755940.0           188.0        NaN           0.0         1.0  ...  32.6
#  1756005.0             NaN        NaN           0.0         1.0  ...   NaN
#  1756196.0           190.0        NaN           0.0         1.0  ...  28.2
#  1756245.0           190.0        NaN           0.0         1.0  ...  25.5
#
#                    SMM  BodyFat    VFA   WHR            CheckDate  \
#  MedicalRecordID
#  1413375.0         NaN      NaN    NaN   NaN                  NaN
#  1446736.0         NaN      NaN    NaN   NaN                  NaN
#  1421521.0         NaN      NaN    NaN   NaN                  NaN
#  1470086.0         NaN      NaN    NaN   NaN                  NaN
#  1421354.0         NaN      NaN    NaN   NaN                  NaN
#  ...               ...      ...    ...   ...                  ...
#  1756011.0         NaN      NaN    NaN   NaN                  NaN
#  1755940.0        34.1     34.4  154.3  0.97  2024-05-14 16:00:00
#  1756005.0         NaN      NaN    NaN   NaN                  NaN
#  1756196.0        23.2     33.2  168.8  0.92  2024-05-14 19:03:00
#  1756245.0        31.3     22.2   97.2  0.92  2024-05-14 20:04:00
#
#                                CrTime  MaxVital  MinVital  Pulse
#  MedicalRecordID
#  1413375.0                        NaN       NaN       NaN    NaN
#  1446736.0                        NaN       NaN       NaN    NaN
#  1421521.0                        NaN       NaN       NaN    NaN
#  1470086.0                        NaN       NaN       NaN    NaN
#  1421354.0                        NaN       NaN       NaN    NaN
#  ...                              ...       ...       ...    ...
#  1756011.0                        NaN       NaN       NaN    NaN
#  1755940.0        2024-05-14 15:02:00     158.0      93.0   97.0
#  1756005.0                        NaN       NaN       NaN    NaN
#  1756196.0        2024-05-14 18:32:45     120.0      78.0   79.0
#  1756245.0        2024-05-14 19:41:17     120.0      76.0   61.0
#
#  [90819 rows x 258 columns],
#  'jamsil':                  PatientID  ScheduleID          ConsultTime  ConsultNote  \
#  MedicalRecordID
#  1561421.0               22   1976771.0  2022-11-26 11:50:00          NaN
#  1562141.0               22   1977491.0  2022-11-28 09:45:00          NaN
#  1585786.0               22   2002026.0  2022-12-21 10:50:00          NaN
#  1704260.0               22   2127590.0  2023-05-16 11:35:00          NaN
#  1719541.0               22   2143926.0  2023-05-30 16:55:00          NaN
#  ...                    ...         ...                  ...          ...
#  1944331.0           358910   2392665.0  2024-05-14 14:15:00          NaN
#  1944446.0           358926   2392911.0  2024-05-14 15:55:00          NaN
#  1944476.0           358941   2393011.0  2024-05-14 16:45:00          NaN
#  1944520.0           358945   2393031.0  2024-05-14 17:45:00          NaN
#  1944560.0           358946   2393041.0  2024-05-14 18:35:00          NaN
#
#                                                        ProgressNote  Summary  \
#  MedicalRecordID
#  1561421.0                                                      NaN      NaN
#  1562141.0                    ★★★★★★★★★★★★★★★선결제 2세트★★★★★★★★★★★★★★★      NaN
#  1585786.0        \n★노은영원장님 휴진으로  방지현원장님께  처방 부탁드립니다.★\n \n# 비만\...      NaN
#  1704260.0         \n# 비만\n\n(접수메모) <챗봇접수> 원장님~ 처방부탁드리겠습니다\n\n신청...      NaN
#  1719541.0         \n#비만 불편증상\n\n★노은영원장님 휴진으로 대체의료진 방지현원장님으로 부탁드...      NaN
#  ...                                                            ...      ...
#  1944331.0        #비만(비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:161.4 / 80 / 중도...      NaN
#  1944446.0        #비만(비대면초진)\n\n· 키/체중/BMI : 180 / 130 / 40.12\n...      NaN
#  1944476.0        # 비만 (비대면초진)\n\n· 키/체중/BMI : 160 / 63 / 24.61\...      NaN
#  1944520.0        #비만 (비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:162 / 86 / 중도 ...      NaN
#  1944560.0        #비만\n\n여자\n\nㆍ 키/체중/BMI:160 / 56 / 정상(21.875)\...      NaN
#
#                   RequestI RequestII  TreatmentCat  Disclosure  ...   BMI  \
#  MedicalRecordID                                                ...
#  1561421.0             NaN       NaN           0.0         1.0  ...   NaN
#  1562141.0             NaN       NaN           0.0         1.0  ...   NaN
#  1585786.0             NaN       NaN           0.0         1.0  ...   NaN
#  1704260.0             NaN       NaN           0.0         1.0  ...   NaN
#  1719541.0             NaN       NaN           0.0         1.0  ...   NaN
#  ...                   ...       ...           ...         ...  ...   ...
#  1944331.0             NaN       NaN           0.0         1.0  ...   NaN
#  1944446.0             NaN       NaN           0.0         1.0  ...   NaN
#  1944476.0             NaN       NaN           0.0         1.0  ...   NaN
#  1944520.0             NaN       NaN           0.0         1.0  ...   NaN
#  1944560.0            59.0       NaN           0.0         1.0  ...  21.4
#
#                    SMM  BodyFat   VFA   WHR            CheckDate  \
#  MedicalRecordID
#  1561421.0         NaN      NaN   NaN   NaN                  NaN
#  1562141.0         NaN      NaN   NaN   NaN                  NaN
#  1585786.0         NaN      NaN   NaN   NaN                  NaN
#  1704260.0         NaN      NaN   NaN   NaN                  NaN
#  1719541.0         NaN      NaN   NaN   NaN                  NaN
#  ...               ...      ...   ...   ...                  ...
#  1944331.0         NaN      NaN   NaN   NaN                  NaN
#  1944446.0         NaN      NaN   NaN   NaN                  NaN
#  1944476.0         NaN      NaN   NaN   NaN                  NaN
#  1944520.0         NaN      NaN   NaN   NaN                  NaN
#  1944560.0        20.7     17.2  75.5  0.85  2024-05-14 18:04:00
#
#                                CrTime  MaxVital  MinVital  Pulse
#  MedicalRecordID
#  1561421.0                        NaN       NaN       NaN    NaN
#  1562141.0                        NaN       NaN       NaN    NaN
#  1585786.0                        NaN       NaN       NaN    NaN
#  1704260.0                        NaN       NaN       NaN    NaN
#  1719541.0                        NaN       NaN       NaN    NaN
#  ...                              ...       ...       ...    ...
#  1944331.0                        NaN       NaN       NaN    NaN
#  1944446.0                        NaN       NaN       NaN    NaN
#  1944476.0                        NaN       NaN       NaN    NaN
#  1944520.0                        NaN       NaN       NaN    NaN
#  1944560.0        2024-05-14 18:43:20     113.0      71.0   95.0
#
#  [103382 rows x 258 columns],
#  'gangnam':                  PatientID  ScheduleID          ConsultTime  ConsultNote  \
#  MedicalRecordID
#  1427925.0                8   1796960.0  2023-11-02 10:15:00          NaN
#  1225621.0               27   1579786.0  2022-11-29 19:00:00          NaN
#  1253520.0               27   1608980.0  2023-01-18 10:40:00          NaN
#  1288586.0               27   1646026.0  2023-03-16 18:15:00          NaN
#  1483200.0               27   1862015.0  2024-03-13 17:10:00          NaN
#  ...                    ...         ...                  ...          ...
#  1509855.0           312730   1892721.0  2024-05-14 14:45:00          NaN
#  1510041.0           312736   1892736.0  2024-05-14 19:10:00          NaN
#  1510011.0           312755   1892896.0  2024-05-14 18:30:00          NaN
#  1510081.0           312765   1892926.0  2024-05-14 19:45:00          NaN
#  1510006.0           312766   1892836.0  2024-05-14 18:15:00          NaN
#
#                                                        ProgressNote  Summary  \
#  MedicalRecordID
#  1427925.0        \n#비만 (내원재진)\n\n* 최고혈압/최저혈압/맥박: ( 105/64/74 ) ...      NaN
#  1225621.0                                                      NaN      NaN
#  1253520.0         \n# 비만\n\n\n신청 약 : 감비정 D2X 405, 팻아웃 3 , 부스터1\...      NaN
#  1288586.0        # 비만\n\n\n신청 약 : 감비정D2X 405, 부스터정 1\n차수 : 2-2차...      NaN
#  1483200.0         \n#비만(전화상담접수)\n\n신청 약 : 감비정L(★리뉴얼) 270,팻아웃 1,...      NaN
#  ...                                                            ...      ...
#  1509855.0        #비만(비대면 초진)\n\n여자\n\nㆍ 키/체중/BMI:166 / 68 / 과체중...      NaN
#  1510041.0        # 비만(내원초진)\n\n· 주소 : 서울 영등포구 당산로 26 103-1401\n...      NaN
#  1510011.0        #비만(비대면 초진)\n\n여자\n\nㆍ 키/체중/BMI:167 / 60 / 정상(...      NaN
#  1510081.0        #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:158 / 58 / 과체중(2...      NaN
#  1510006.0        # 비만(비대면초진) \n\n· 주소 : 세종특별자치시 조치원읍 이화1로 15 10...      NaN
#
#                   RequestI  RequestII  TreatmentCat  Disclosure  ...   BMI  \
#  MedicalRecordID                                                 ...
#  1427925.0           115.0        NaN           0.0         1.0  ...  23.2
#  1225621.0             NaN        NaN           0.0         1.0  ...   NaN
#  1253520.0            38.0        NaN           0.0         1.0  ...   NaN
#  1288586.0            36.0        NaN           0.0         1.0  ...   NaN
#  1483200.0            79.0        NaN           0.0         1.0  ...   NaN
#  ...                   ...        ...           ...         ...  ...   ...
#  1509855.0            70.0        NaN           0.0         1.0  ...   NaN
#  1510041.0            59.0        NaN           0.0         1.0  ...  26.1
#  1510011.0            58.0        NaN           0.0         1.0  ...   NaN
#  1510081.0            60.0        NaN           0.0         1.0  ...  23.8
#  1510006.0             NaN        NaN           0.0         1.0  ...   NaN
#
#                    SMM  BodyFat    VFA   WHR            CheckDate  \
#  MedicalRecordID
#  1427925.0        23.0     21.4   98.1  0.86  2023-11-02 00:02:05
#  1225621.0         NaN      NaN    NaN   NaN                  NaN
#  1253520.0         NaN      NaN    NaN   NaN                  NaN
#  1288586.0         NaN      NaN    NaN   NaN                  NaN
#  1483200.0         NaN      NaN    NaN   NaN                  NaN
#  ...               ...      ...    ...   ...                  ...
#  1509855.0         NaN      NaN    NaN   NaN                  NaN
#  1510041.0        22.3     21.0   94.8  0.92  2024-05-14 00:03:00
#  1510011.0         NaN      NaN    NaN   NaN                  NaN
#  1510081.0        19.5     23.0  113.8  0.82  2024-05-14 00:05:00
#  1510006.0         NaN      NaN    NaN   NaN                  NaN
#
#                                CrTime  MaxVital  MinVital  Pulse
#  MedicalRecordID
#  1427925.0        2023-11-02 10:27:12     105.0      64.0   74.0
#  1225621.0                        NaN       NaN       NaN    NaN
#  1253520.0                        NaN       NaN       NaN    NaN
#  1288586.0                        NaN       NaN       NaN    NaN
#  1483200.0                        NaN       NaN       NaN    NaN
#  ...                              ...       ...       ...    ...
#  1509855.0                        NaN       NaN       NaN    NaN
#  1510041.0        2024-05-14 19:30:54     124.0      83.0   85.0
#  1510011.0                        NaN       NaN       NaN    NaN
#  1510081.0        2024-05-14 19:55:17     125.0      74.0   79.0
#  1510006.0                        NaN       NaN       NaN    NaN
#
#  [77225 rows x 258 columns],
#  'incheon':                  PatientID  ScheduleID          ConsultTime  ConsultNote  \
#  MedicalRecordID
#  6045.0                  50      7315.0  2023-06-17 11:10:00          NaN
#  6511.0                  50      8241.0  2023-06-21 09:10:00          NaN
#  12061.0                 50      7706.0  2023-07-22 11:35:00          NaN
#  181.0                   55       105.0  2023-04-29 12:15:00          NaN
#  9680.0                  55     11001.0  2023-07-08 11:50:00          NaN
#  ...                    ...         ...                  ...          ...
#  53615.0              21816     61480.0  2024-05-14 13:05:00          NaN
#  53625.0              21821     61490.0  2024-05-14 13:05:00          NaN
#  53661.0              21836     61545.0  2024-05-14 15:50:00          NaN
#  53666.0              21840     61546.0  2024-05-14 16:15:00          NaN
#  53676.0              21841     61556.0  2024-05-14 16:50:00          NaN
#
#                                                        ProgressNote  Summary  \
#  MedicalRecordID
#  6045.0           #비만\n\n여자\n\nㆍ 키/체중/BMI:166 / 59 / 정상(21.41094...      NaN
#  6511.0            \n# 비만\n\n<URL or 아웃콜 감비정(감비엑스) 복용 1일차 체크상담>\...      NaN
#  12061.0          \n# 비만\n\n*체      중: (  56.8  )\n*골격근량: (   21...      NaN
#  181.0            \n#비만\n\n* 최고혈압/최저혈압/맥박: ( 121/ 74/ 77) \n* 키/...      NaN
#  9680.0           \n# 비만\n\n*체      중: (  71.1 ) -3.4\n*골격근량: ( ...      NaN
#  ...                                                            ...      ...
#  53615.0          #비만(전화상담접수)\n\n★마지막처방일 5년경과 의료진 확인사항 \n현재체중 : ...      NaN
#  53625.0          #비만(비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:156 / 72 / 경도비만...      NaN
#  53661.0          #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:162 / 73 / 경도비만(...      NaN
#  53666.0          #비만(내원초진)\n\n남자\n\nㆍ 키/체중/BMI:173 / 99.9 / 중도 ...      NaN
#  53676.0          # 비만(비대면초진)\n\n· 키/체중/BMI : 177 / 88 / 28.09\n...      NaN
#
#                   RequestI  RequestII  TreatmentCat  Disclosure  ...   BMI  \
#  MedicalRecordID                                                 ...
#  6045.0               19.0        NaN           0.0         1.0  ...  21.1
#  6511.0                NaN        NaN           0.0         1.0  ...   NaN
#  12061.0               8.0        NaN           0.0         1.0  ...  20.3
#  181.0                10.0        NaN           0.0         1.0  ...  28.0
#  9680.0                8.0        NaN           0.0         1.0  ...  26.8
#  ...                   ...        ...           ...         ...  ...   ...
#  53615.0               9.0        NaN           0.0         1.0  ...   NaN
#  53625.0               NaN        NaN           0.0         1.0  ...   NaN
#  53661.0              13.0        NaN           0.0         1.0  ...  29.7
#  53666.0              16.0        NaN           0.0         1.0  ...  32.6
#  53676.0               NaN        NaN           0.0         1.0  ...   NaN
#
#                    SMM  BodyFat    VFA   WHR            CheckDate  \
#  MedicalRecordID
#  6045.0           20.9     20.0   89.4  0.83  2023-06-17 11:00:00
#  6511.0            NaN      NaN    NaN   NaN                  NaN
#  12061.0          21.1     17.5   71.6  0.82  2023-07-22 11:00:00
#  181.0            26.4     27.0  132.1  0.97  2023-04-29 12:00:05
#  9680.0           26.0     24.1  111.8  0.93  2023-07-08 11:00:00
#  ...               ...      ...    ...   ...                  ...
#  53615.0           NaN      NaN    NaN   NaN                  NaN
#  53625.0           NaN      NaN    NaN   NaN                  NaN
#  53661.0          25.5     31.1  163.0  0.98  2024-05-14 15:05:00
#  53666.0          37.0     33.7  157.1  1.03  2024-05-14 16:01:00
#  53676.0           NaN      NaN    NaN   NaN                  NaN
#
#                                CrTime  MaxVital  MinVital  Pulse
#  MedicalRecordID
#  6045.0           2023-06-17 11:22:55     112.0      70.0   89.0
#  6511.0                           NaN       NaN       NaN    NaN
#  12061.0          2023-07-22 11:33:36     116.0      79.0   98.0
#  181.0            2023-04-29 12:27:31     121.0      74.0   77.0
#  9680.0           2023-07-08 11:42:12     125.0      73.0   89.0
#  ...                              ...       ...       ...    ...
#  53615.0                          NaN       NaN       NaN    NaN
#  53625.0                          NaN       NaN       NaN    NaN
#  53661.0          2024-05-14 16:07:23     133.0      85.0   93.0
#  53666.0          2024-05-14 16:24:48     148.0      97.0   84.0
#  53676.0                          NaN       NaN       NaN    NaN
#
#  [12383 rows x 258 columns]}

# %%
Merge.regionCol()

# %%
df = Merge.concatData()

# %%
Merge.delZeroNaNCol(df)
# Out:
# 처리된 데이터프레임:
#                  PatientID  ScheduleID          ConsultTime ConsultNote  \
# MedicalRecordID
# 876726.0                 9   1126286.0  2022-11-23 10:55:00         NaN
# 942106.0                 9   1195711.0  2023-02-16 09:45:00         NaN
# 943030.0                 9   1196745.0  2023-02-17 10:25:00         NaN
# 956320.0                 9   1210915.0  2023-03-07 19:20:00         NaN
# 956596.0                 9   1211226.0  2023-03-08 09:25:00         NaN
# ...                    ...         ...                  ...         ...
# 53615.0              21816     61480.0  2024-05-14 13:05:00         NaN
# 53625.0              21821     61490.0  2024-05-14 13:05:00         NaN
# 53661.0              21836     61545.0  2024-05-14 15:50:00         NaN
# 53666.0              21840     61546.0  2024-05-14 16:15:00         NaN
# 53676.0              21841     61556.0  2024-05-14 16:50:00         NaN
#
#                                                       ProgressNote  RequestI  \
# MedicalRecordID
# 876726.0         # 비만\n\n현재체중 : 65kg\n마지막 약 복용일자 : 복용 중\n포만감&식사...      25.0
# 942106.0                                                       NaN      24.0
# 943030.0         # 비만\n\n현재체중 : 65kg\n마지막 약 복용일자 : 복용 중\n포만감&식사...       NaN
# 956320.0                                                       NaN       NaN
# 956596.0                                    # 비만\n\n>> 팻아웃플러스 9통         NaN
# ...                                                            ...       ...
# 53615.0          #비만(전화상담접수)\n\n★마지막처방일 5년경과 의료진 확인사항 \n현재체중 : ...       9.0
# 53625.0          #비만(비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:156 / 72 / 경도비만...       NaN
# 53661.0          #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:162 / 73 / 경도비만(...      13.0
# 53666.0          #비만(내원초진)\n\n남자\n\nㆍ 키/체중/BMI:173 / 99.9 / 중도 ...      16.0
# 53676.0          # 비만(비대면초진)\n\n· 키/체중/BMI : 177 / 88 / 28.09\n...       NaN
#
#                 RequestII  Disclosure  NonInsAmt  Bookmark  ...   SMM  \
# MedicalRecordID                                             ...
# 876726.0              NaN         1.0    50000.0       0.0  ...   NaN
# 942106.0              NaN         1.0   330000.0       0.0  ...   NaN
# 943030.0              NaN         1.0        0.0       0.0  ...   NaN
# 956320.0              NaN         1.0   150000.0       0.0  ...   NaN
# 956596.0              NaN         1.0        0.0       0.0  ...   NaN
# ...                   ...         ...        ...       ...  ...   ...
# 53615.0               NaN         1.0   165000.0       0.0  ...   NaN
# 53625.0               NaN         1.0   200000.0       0.0  ...   NaN
# 53661.0               NaN         1.0    30000.0       0.0  ...  25.5
# 53666.0               NaN         1.0    30000.0       0.0  ...  37.0
# 53676.0               NaN         1.0    15000.0       0.0  ...   NaN
#
#                  BodyFat    VFA   WHR            CheckDate  \
# MedicalRecordID
# 876726.0             NaN    NaN   NaN                  NaN
# 942106.0             NaN    NaN   NaN                  NaN
# 943030.0             NaN    NaN   NaN                  NaN
# 956320.0             NaN    NaN   NaN                  NaN
# 956596.0             NaN    NaN   NaN                  NaN
# ...                  ...    ...   ...                  ...
# 53615.0              NaN    NaN   NaN                  NaN
# 53625.0              NaN    NaN   NaN                  NaN
# 53661.0             31.1  163.0  0.98  2024-05-14 15:05:00
# 53666.0             33.7  157.1  1.03  2024-05-14 16:01:00
# 53676.0              NaN    NaN   NaN                  NaN
#
#                               CrTime  MaxVital  MinVital  Pulse   Region
# MedicalRecordID
# 876726.0                         NaN       NaN       NaN    NaN  bucheon
# 942106.0                         NaN       NaN       NaN    NaN  bucheon
# 943030.0                         NaN       NaN       NaN    NaN  bucheon
# 956320.0                         NaN       NaN       NaN    NaN  bucheon
# 956596.0                         NaN       NaN       NaN    NaN  bucheon
# ...                              ...       ...       ...    ...      ...
# 53615.0                          NaN       NaN       NaN    NaN  incheon
# 53625.0                          NaN       NaN       NaN    NaN  incheon
# 53661.0          2024-05-14 16:07:23     133.0      85.0   93.0  incheon
# 53666.0          2024-05-14 16:24:48     148.0      97.0   84.0  incheon
# 53676.0                          NaN       NaN       NaN    NaN  incheon
#
# [512591 rows x 234 columns]
#
# 삭제된 열 이름:
# Index(['Additional', 'AidAmt', 'DetailMemo', 'DisabledAidAmt', 'Discarded',
#        'DiscountAmt', 'HealthCareAmt', 'Ins100Amt', 'InsChargeAmt',
#        'InsClaimAmt', 'InsTotalAmt', 'InsuranceType', 'LicNo', 'LossAmt',
#        'LtChargeAmt', 'LtClaimAmt', 'MedicalRecordID_ORG', 'MedicationID_ORG',
#        'ModTime', 'PregGrantAmt', 'SourceProgram', 'Summary', 'TDiscountAmt',
#        'TaxableAmt', 'TreatmentCat'],
#       dtype='object')

# %%
group_sizes = df.groupby('PatientID').size()

# %%
# 그룹 크기가 1인 PatientID 필터링
single_patient_ids = group_sizes[group_sizes == 1].index
multiple_patient_ids1 = group_sizes[(group_sizes > 1) & (group_sizes <= 5)].index
multiple_patient_ids2 = group_sizes[(group_sizes > 5) & (group_sizes <= 9)].index
multiple_patient_ids3 = group_sizes[9 < group_sizes].index

# 필터링된 데이터 프레임
df_1 = df[df['PatientID'].isin(single_patient_ids)]
df_5 = df[df['PatientID'].isin(multiple_patient_ids1)]
df_10 = df[df['PatientID'].isin(multiple_patient_ids2)]
df_50 = df[df['PatientID'].isin(multiple_patient_ids3)]

# %%
len(df_1) ,len(df_5), len(df_10),  len(df_50) , len(df)
# Out:
# (17698, 193119, 196080, 134404, 512591)

# %%
# 데이터 병합
result_df50 = process_and_merge(df_50)

# 결과 확인
print("\nNew DataFrame with merged rows:")

new_columns =['PatientID']
columns = result_df50.columns
for num in range(1, 10):
    imsi_list = [column for column in columns if column[-2:] == '_'+str(num)]
    #print(imsi_list)
    new_columns = new_columns + imsi_list
for num in range(10, 49):
    imsi_list = [column for column in columns if column[-2:] == str(num)]
    new_columns = new_columns + imsi_list

result_df50 = result_df50[new_columns]
print(result_df50)
result_df50.to_csv(f'{Merge.newPath}\\platten_50.csv', index = False)
# Out:
# New DataFrame with merged rows:
#        PatientID  ScheduleID_1        ConsultTime_1  ConsultNote_1  \
# 0              9     1126286.0  2022-11-23 10:55:00            NaN
# 1             37     1208375.0  2023-03-06 16:10:00            NaN
# 2             69     1143596.0  2022-12-10 11:15:00            NaN
# 3             82     1141960.0  2022-12-02 10:25:00            NaN
# 4            105     1216486.0  2023-03-10 16:30:00            NaN
# ...          ...           ...                  ...            ...
# 10575     296866     1774901.0  2023-09-21 10:05:00            NaN
# 10576     297210     1776770.0  2023-09-19 12:10:00            NaN
# 10577     297235     1777025.0  2023-09-18 11:30:00            NaN
# 10578     298546     1819601.0  2023-12-18 10:40:00            NaN
# 10579     304641     1844946.0  2024-02-01 16:25:00            NaN
#
#                                           ProgressNote_1  Summary_1  \
# 0      # 비만\n\n현재체중 : 65kg\n마지막 약 복용일자 : 복용 중\n포만감&식사...        NaN
# 1                                     # 비만\n\n>> 팻아웃 6통         NaN
# 2      #비만\n\n남자\n\nㆍ 키/체중/BMI:177 / 90 / 경도비만(28.727...        NaN
# 3                                                    NaN        NaN
# 4                                      # 비만\n\n>> 팻아웃 6통        NaN
# ...                                                  ...        ...
# 10575  #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:155 / 60 / (24.9...        NaN
# 10576  #비만 (내원초진)\n\n여자\n\nㆍ 키/체중/BMI:16168 / 68 / 저체...        NaN
# 10577  #비만\n\n여자\n\nㆍ 키/체중/BMI:162 / 79 / 중도 비만(30.10...        NaN
# 10578  #비만\n\n여자\n\nㆍ 키/체중/BMI:155 / 53 / 정상(22.06035...        NaN
# 10579  #비만 (비대면초진) \n\n**처방대기/ 항불안제 약명확인 필요/ 약명확인 후 D...        NaN
#
#        RequestI_1  RequestII_1  TreatmentCat_1  Disclosure_1  ...  SMM_48  \
# 0            25.0          NaN             0.0           1.0  ...     NaN
# 1             NaN          NaN             0.0           1.0  ...     NaN
# 2             2.0          NaN             0.0           1.0  ...     NaN
# 3             NaN          NaN             0.0           1.0  ...     NaN
# 4             NaN          NaN             0.0           1.0  ...     NaN
# ...           ...          ...             ...           ...  ...     ...
# 10575        93.0          NaN             0.0           1.0  ...     NaN
# 10576        87.0          NaN             0.0           1.0  ...     NaN
# 10577        87.0          NaN             0.0           1.0  ...     NaN
# 10578         NaN          NaN             0.0           1.0  ...     NaN
# 10579         NaN          NaN             0.0           1.0  ...     NaN
#
#        BodyFat_48  VFA_48  WHR_48  CheckDate_48  CrTime_48  MaxVital_48  \
# 0             NaN     NaN     NaN           NaN        NaN          NaN
# 1             NaN     NaN     NaN           NaN        NaN          NaN
# 2             NaN     NaN     NaN           NaN        NaN          NaN
# 3             NaN     NaN     NaN           NaN        NaN          NaN
# 4             NaN     NaN     NaN           NaN        NaN          NaN
# ...           ...     ...     ...           ...        ...          ...
# 10575         NaN     NaN     NaN           NaN        NaN          NaN
# 10576         NaN     NaN     NaN           NaN        NaN          NaN
# 10577         NaN     NaN     NaN           NaN        NaN          NaN
# 10578         NaN     NaN     NaN           NaN        NaN          NaN
# 10579         NaN     NaN     NaN           NaN        NaN          NaN
#
#        MinVital_48  Pulse_48  Region_48
# 0              NaN       NaN        NaN
# 1              NaN       NaN        NaN
# 2              NaN       NaN        NaN
# 3              NaN       NaN        NaN
# 4              NaN       NaN        NaN
# ...            ...       ...        ...
# 10575          NaN       NaN        NaN
# 10576          NaN       NaN        NaN
# 10577          NaN       NaN        NaN
# 10578          NaN       NaN        NaN
# 10579          NaN       NaN        NaN
#
# [10580 rows x 12385 columns]

# %%
# 데이터 병합
result_df10 = process_and_merge(df_10)

# 결과 확인
print("\nNew DataFrame with merged rows:")
columns = result_df10.columns
new_columns =['PatientID']

for num in range(1, 10):
    imsi_list = [column for column in columns if column[-2:] == '_'+str(num)]
    #print(imsi_list)
    new_columns = new_columns + imsi_list


result_df10 = result_df10[new_columns]
print(result_df10)
result_df10.to_csv(f'{Merge.newPath}\\platten_10.csv', index = False)
# Out:
# New DataFrame with merged rows:
#        PatientID  ScheduleID_1        ConsultTime_1  ConsultNote_1  \
# 0             19     1134186.0  2022-11-28 17:45:00            NaN
# 1             50     1139246.0  2022-12-01 14:05:00            NaN
# 2             72     1242330.0  2023-04-12 14:10:00            NaN
# 3            201     1210756.0  2023-03-07 18:50:00            NaN
# 4            227     1190540.0  2023-02-08 19:15:00            NaN
# ...          ...           ...                  ...            ...
# 26200      17600       50060.0  2024-03-12 11:15:00            NaN
# 26201      18510       52606.0  2024-03-23 11:15:00            NaN
# 26202      19096       54246.0  2024-04-11 18:55:00            NaN
# 26203      19791       56161.0  2024-04-11 14:30:00            NaN
# 26204      20711       58556.0  2024-04-25 14:25:00            NaN
#
#                                           ProgressNote_1  Summary_1  \
# 0       \n# 비만\n\n현재체중 : 60kg\n마지막 약 복용일자 : 복용 중\n포만감...        NaN
# 1                                                    NaN        NaN
# 2       \n# 비만\n\n제형:감비정 \n현재체중 :58kg\n포만감&식사조절:잘됨\n불...        NaN
# 3                                                    NaN        NaN
# 4      \n# 비만\n\n*체      중: (  67.8 )\n*골격근량: (  21.8...        NaN
# ...                                                  ...        ...
# 26200  #비만(비대면초진)\n\n여자\n\nㆍ 키/체중/BMI:163 / 69.5 / 경도...        NaN
# 26201  # 비만(기타) \n\n<카톡접수> 약 병용 확인 \n\n약 복용 사유 : 고혈압 ...        NaN
# 26202  #비만(내원초진)\n\n· 키/체중/BMI : 152/47/20.34\n· 결혼 상...        NaN
# 26203  #비만(비대면초진)\n\n· 주소 :  인천시 중구 중산동 하늘달빛로139 762동...        NaN
# 26204  # 비만(비대면초진)\n\n· 주소 : 인천 미추홀구 제일로27번길 21-8 그랜트...        NaN
#
#        RequestI_1  RequestII_1  TreatmentCat_1  Disclosure_1  ...  SMM_9  \
# 0            25.0          NaN             0.0           1.0  ...    NaN
# 1             NaN          NaN             0.0           1.0  ...    NaN
# 2            25.0          NaN             0.0           1.0  ...    NaN
# 3             NaN          NaN             0.0           1.0  ...    NaN
# 4            24.0          NaN             0.0           1.0  ...    NaN
# ...           ...          ...             ...           ...  ...    ...
# 26200         4.0          NaN             0.0           1.0  ...    NaN
# 26201         NaN          NaN             0.0           1.0  ...    NaN
# 26202         NaN          NaN             0.0           1.0  ...    NaN
# 26203         7.0          NaN             0.0           1.0  ...    NaN
# 26204         NaN          NaN             0.0           1.0  ...    NaN
#
#        BodyFat_9  VFA_9  WHR_9  CheckDate_9  CrTime_9  MaxVital_9  MinVital_9  \
# 0            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 1            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 2            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 3            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 4            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# ...          ...    ...    ...          ...       ...         ...         ...
# 26200        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 26201        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 26202        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 26203        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 26204        NaN    NaN    NaN          NaN       NaN         NaN         NaN
#
#        Pulse_9  Region_9
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN   bucheon
# 4          NaN       NaN
# ...        ...       ...
# 26200      NaN       NaN
# 26201      NaN       NaN
# 26202      NaN   incheon
# 26203      NaN       NaN
# 26204      NaN       NaN
#
# [26205 rows x 2323 columns]

# %%
# 데이터 병합
result_df5 = process_and_merge(df_5)

# 결과 확인
print("\nNew DataFrame with merged rows:")

columns = result_df5.columns
new_columns =['PatientID']
for num in range(1, 6):
    imsi_list = [column for column in columns if column[-2:] == '_'+str(num)]
    #print(imsi_list)
    new_columns = new_columns + imsi_list


result_df5 = result_df5[new_columns]
print(result_df5)
result_df5.to_csv(f'{Merge.newPath}\\platten_5.csv', index = False)
# Out:
# New DataFrame with merged rows:
#        PatientID  ScheduleID_1        ConsultTime_1 ConsultNote_1  \
# 0             14     1309095.0  2023-06-29 14:50:00           NaN
# 1             29     1117491.0  2022-11-11 14:40:00           NaN
# 2             39     1142876.0  2022-12-02 16:05:00           NaN
# 3             68     1117415.0  2022-11-11 11:40:00           NaN
# 4            127     1128576.0  2022-11-24 15:30:00           NaN
# ...          ...           ...                  ...           ...
# 58764      21560       60700.0  2024-05-09 09:45:00           NaN
# 58765      21711       61415.0  2024-05-13 19:05:00           NaN
# 58766      21721       61281.0  2024-05-13 14:20:00           NaN
# 58767      21780       61335.0  2024-05-13 16:05:00           NaN
# 58768      21781       61326.0  2024-05-13 18:05:00           NaN
#
#                                           ProgressNote_1  Summary_1  \
# 0                                                    NaN        NaN
# 1       \n# 비만\n\n현재체중 : 58kg\n마지막 약 복용일자 : 복용 중\n포만감...        NaN
# 2      # 비만\n\n<미 내원 2년 이상>\n*현재 체중:85kg\n*최근 6개월 내 다...        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 58764  #비만(내원재진) - 지점이동\n\n* 최고혈압/최저혈압/맥박: ( 123/ 70/...        NaN
# 58765  #비만(전화상담접수)\n\n현재체중 : 106\n포만감 또는 식욕조절 : 보통\n불...        NaN
# 58766  #비만(전화상담접수) - 지점이동\n\n현재체중 : 92kg\n포만감 또는 식욕조절...        NaN
# 58767  #비만(비대면초진)\n\n남자\n\nㆍ 키/체중/BMI:182 / 97 / 경도비만...        NaN
# 58768  # 비만(비대면초진)\n\n· 키/체중/BMI : 160 / 70 / 27.34\n...        NaN
#
#        RequestI_1  RequestII_1  TreatmentCat_1  Disclosure_1  ...  SMM_5  \
# 0            80.0          NaN             0.0           1.0  ...    NaN
# 1            25.0          NaN             0.0           1.0  ...    NaN
# 2            24.0          NaN             0.0           1.0  ...    NaN
# 3             NaN          NaN             0.0           1.0  ...    NaN
# 4            25.0          NaN             0.0           1.0  ...    NaN
# ...           ...          ...             ...           ...  ...    ...
# 58764        10.0          NaN             0.0           1.0  ...    NaN
# 58765        11.0          NaN             0.0           1.0  ...    NaN
# 58766         NaN          NaN             0.0           1.0  ...    NaN
# 58767         NaN          NaN             0.0           1.0  ...    NaN
# 58768         NaN          NaN             0.0           1.0  ...    NaN
#
#        BodyFat_5  VFA_5  WHR_5  CheckDate_5  CrTime_5  MaxVital_5  MinVital_5  \
# 0            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 1            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 2            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 3            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 4            NaN    NaN    NaN          NaN       NaN         NaN         NaN
# ...          ...    ...    ...          ...       ...         ...         ...
# 58764        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 58765        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 58766        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 58767        NaN    NaN    NaN          NaN       NaN         NaN         NaN
# 58768        NaN    NaN    NaN          NaN       NaN         NaN         NaN
#
#        Pulse_5  Region_5
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN   bucheon
# 4          NaN   bucheon
# ...        ...       ...
# 58764      NaN       NaN
# 58765      NaN       NaN
# 58766      NaN       NaN
# 58767      NaN       NaN
# 58768      NaN       NaN
#
# [58769 rows x 1291 columns]

# %%
result_df1 = df_1
print(result_df1)
# Out:
#                  PatientID  ScheduleID          ConsultTime ConsultNote  \
# MedicalRecordID
# 884214.0               183   1134009.0  2022-11-28 16:40:00         NaN
# 1165140.0              211   1444451.0  2024-02-13 18:25:00         NaN
# 1184781.0              217   1468981.0  2024-03-29 12:35:00         NaN
# 892956.0               293   1143046.0  2022-12-02 17:00:00         NaN
# 1197250.0              324   1485715.0  2024-05-03 11:35:00         NaN
# ...                    ...         ...                  ...         ...
# 53506.0              21785     61386.0  2024-05-13 17:25:00         NaN
# 53620.0              21796     61391.0  2024-05-14 13:05:00         NaN
# 53661.0              21836     61545.0  2024-05-14 15:50:00         NaN
# 53666.0              21840     61546.0  2024-05-14 16:15:00         NaN
# 53676.0              21841     61556.0  2024-05-14 16:50:00         NaN
#
#                                                       ProgressNote  Summary  \
# MedicalRecordID
# 884214.0         # 비만\n\n현재체중 : 64kg\n마지막 약 복용일자 : 3개월전\n포만감&식사...      NaN
# 1165140.0        #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:168 / 73 / 경도비만(...      NaN
# 1184781.0        #비만(내원재진)\n\n*혈압: 112/69/81\n*체 중: (57.7 ) +\n...      NaN
# 892956.0         # 비만\n\n현재체중 : 52kg\n마지막 약 복용일자 : 1개월 이상\n포만감&...      NaN
# 1197250.0        #비만(전화접수)\n\n현재체중 : 89\n포만감 또는 식욕조절 : 적당함\n불편사...      NaN
# ...                                                            ...      ...
# 53506.0          #비만(비대면초진)\n\n남자\n\nㆍ 키/체중/BMI:180 / 93 / 경도비만...      NaN
# 53620.0          # 비만(비대면초진)\n\n· 키/체중/BMI : 155 / 51 / 21.23\n...      NaN
# 53661.0          #비만(내원초진)\n\n여자\n\nㆍ 키/체중/BMI:162 / 73 / 경도비만(...      NaN
# 53666.0          #비만(내원초진)\n\n남자\n\nㆍ 키/체중/BMI:173 / 99.9 / 중도 ...      NaN
# 53676.0          # 비만(비대면초진)\n\n· 키/체중/BMI : 177 / 88 / 28.09\n...      NaN
#
#                  RequestI RequestII  TreatmentCat  Disclosure  ...   SMM  \
# MedicalRecordID                                                ...
# 884214.0             24.0       NaN           0.0         1.0  ...   NaN
# 1165140.0           200.0       NaN           0.0         1.0  ...  23.0
# 1184781.0           118.0       NaN           0.0         1.0  ...  22.4
# 892956.0             25.0       NaN           0.0         1.0  ...   NaN
# 1197250.0           100.0       NaN           0.0         1.0  ...   NaN
# ...                   ...       ...           ...         ...  ...   ...
# 53506.0               NaN       NaN           0.0         1.0  ...   NaN
# 53620.0               NaN       NaN           0.0         1.0  ...   NaN
# 53661.0              13.0       NaN           0.0         1.0  ...  25.5
# 53666.0              16.0       NaN           0.0         1.0  ...  37.0
# 53676.0               NaN       NaN           0.0         1.0  ...   NaN
#
#                  BodyFat    VFA   WHR            CheckDate  \
# MedicalRecordID
# 884214.0             NaN    NaN   NaN                  NaN
# 1165140.0           30.4  166.6  0.98  2024-02-13 18:03:00
# 1184781.0           16.0   71.4  0.86  2024-03-29 12:00:00
# 892956.0             NaN    NaN   NaN                  NaN
# 1197250.0            NaN    NaN   NaN                  NaN
# ...                  ...    ...   ...                  ...
# 53506.0              NaN    NaN   NaN                  NaN
# 53620.0              NaN    NaN   NaN                  NaN
# 53661.0             31.1  163.0  0.98  2024-05-14 15:05:00
# 53666.0             33.7  157.1  1.03  2024-05-14 16:01:00
# 53676.0              NaN    NaN   NaN                  NaN
#
#                               CrTime  MaxVital  MinVital  Pulse   Region
# MedicalRecordID
# 884214.0                         NaN       NaN       NaN    NaN  bucheon
# 1165140.0        2024-02-13 18:40:59     125.0      71.0   66.0  bucheon
# 1184781.0        2024-03-29 12:25:37     112.0      69.0   81.0  bucheon
# 892956.0                         NaN       NaN       NaN    NaN  bucheon
# 1197250.0                        NaN       NaN       NaN    NaN  bucheon
# ...                              ...       ...       ...    ...      ...
# 53506.0                          NaN       NaN       NaN    NaN  incheon
# 53620.0                          NaN       NaN       NaN    NaN  incheon
# 53661.0          2024-05-14 16:07:23     133.0      85.0   93.0  incheon
# 53666.0          2024-05-14 16:24:48     148.0      97.0   84.0  incheon
# 53676.0                          NaN       NaN       NaN    NaN  incheon
#
# [17698 rows x 259 columns]

# %%
byPatientID1 = pd.concat([result_df1, result_df5], axis = 0, join ='outer')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 byPatientID1 = pd.concat([result_df1, result_df5], axis = 0, join ='outer')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
# --> 680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#     683 if not self.copy and not using_copy_on_write():
#     684     new_data._consolidate_inplace()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\concat.py:189, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     187     fastpath = blk.values.dtype == values.dtype
#     188 else:
# --> 189     values = _concatenate_join_units(join_units, copy=copy)
#     190     fastpath = False
#     192 if fastpath:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\concat.py:486, in _concatenate_join_units(join_units, copy)
#     483     concat_values = ensure_block_shape(concat_values, 2)
#     485 else:
# --> 486     concat_values = concat_compat(to_concat, axis=1)
#     488 if empty_dtype != empty_dtype_future:
#     489     if empty_dtype == concat_values.dtype:
#     490         # GH#39122, GH#40893
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\concat.py:78, in concat_compat(to_concat, axis, ea_compat_axis)
#      76 if isinstance(obj, np.ndarray):
#      77     to_concat_arrs = cast("Sequence[np.ndarray]", to_concat)
# ---> 78     return np.concatenate(to_concat_arrs, axis=axis)
#      80 to_concat_eas = cast("Sequence[ExtensionArray]", to_concat)
#      81 if ea_compat_axis:
#      82     # We have 1D objects, that don't support axis keyword
#
# MemoryError: Unable to allocate 107. MiB for an array with shape (183, 76467) and data type float64

# %%
byPatientID2 = pd.concat([result_df10, result_df50], axis = 0, join ='outer')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 byPatientID2 = pd.concat([result_df10, result_df50], axis = 0, join ='outer')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
# --> 680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#     683 if not self.copy and not using_copy_on_write():
#     684     new_data._consolidate_inplace()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\concat.py:177, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     167 vals = [ju.block.values for ju in join_units]
#     169 if not blk.is_extension:
#     170     # _is_uniform_join_units ensures a single dtype, so
#     171     #  we can use np.concatenate, which is more performant
#    (...)
#     175     # expected "Union[_SupportsArray[dtype[Any]],
#     176     # _NestedSequence[_SupportsArray[dtype[Any]]]]"
# --> 177     values = np.concatenate(vals, axis=1)  # type: ignore[arg-type]
#     178 elif is_1d_only_ea_dtype(blk.dtype):
#     179     # TODO(EA2D): special-casing not needed with 2D EAs
#     180     values = concat_compat(vals, axis=0, ea_compat_axis=True)
#
# MemoryError: Unable to allocate 51.4 MiB for an array with shape (183, 36785) and data type float64

# %%
byPatientID.shape, df.shape,
#(17698, 193119, 196080, 134404, 512591)
# Out:
# ((113252, 1), (512591, 259))

# %%
len(set(df['PatientID']))
# Out:
# 110381
